# %%
#!/usr/bin/env python2

import os
import sys
import glob
import threading

import numpy as np
from PIL import Image

import cv2

# %%
resize_ratio = 1/2.


def mkdir(path):
    if os.path.isdir(path) is False:
        os.mkdir(path)


def extract_video(video_file, output_dir, frames, jpeg_quality=95):

    try:
        vidcap = cv2.VideoCapture(video_file)
    except Exception as e:
        sys.stderr.write(str(e) + '\n')
        sys.stderr.write('Error loading file "{}"\n'.format(video_file))
        return

    mkdir(output_dir)
    sys.stdout.write('Extracting video "{}"\n'.format(video_file))
    sys.stdout.flush()

    f = 0
    while True:
        success, image = vidcap.read()
        f += 1
        if not success:
            break
        if f not in frames:
            continue # Skip if not in the frame list

        ncols, nrows, rgb = image.shape
        dsize = (int(resize_ratio*nrows), int(resize_ratio*ncols))
        image = cv2.resize(image, dsize, interpolation=cv2.INTER_CUBIC)

        frame_file = os.path.join(output_dir, '%05d.jpg' % f)
        cv2.imwrite(frame_file, image,
                [cv2.IMWRITE_JPEG_QUALITY, jpeg_quality])

    vidcap.release()


def extract_resize_videos(input_path, output_path, annot_path, subjects,
        num_C=3, num_P=40, num_R=2, num_A=60):

    if os.path.isdir(input_path) is False:
        raise Exception('Could not find the "{}" folder!'.format(input_path))

    mkdir(output_path)

    for s in subjects:
        for c in range(1,num_C+1):
            for p in range(1,num_P+1):
                for r in range(1,num_R+1):
                    for a in range(1,num_A+1):

                        sequence_id = 'S%03dC%03dP%03dR%03dA%03d' \
                                % (s, c, p, r, a)

                        video_file = os.path.join(input_path,
                                sequence_id + '_rgb.avi')

                        annot_file = os.path.join(annot_path,
                                sequence_id + '.npy')
                        if not os.path.isfile(annot_file):
                            continue # Ignore missing annotation files

                        annot = np.load(annot_file)
                        # frames = annot[1::2,0] # Divide video fps by 2
                        frames = annot[:,0]

                        output_dir = os.path.join(output_path, sequence_id)
                        extract_video(video_file, output_dir, frames)

# %%
annot_path = './data/ntu/annotations/test_annot'
out_path = './data/ntu/images-small'
input_path = './data/ntu/videos'
extract_resize_videos(input_path, out_path, annot_path,list(range(17)))
# Out:
# Extracting video "./data/ntu/videos/S001C001P001R001A001_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A002_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A003_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A004_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A005_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A006_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A007_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A008_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A009_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A010_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A011_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A012_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A013_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A014_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A015_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A016_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A017_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A018_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A019_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A020_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A021_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A022_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A023_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A024_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A025_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A026_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A027_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A028_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A029_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A030_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A031_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A032_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A033_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A034_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A035_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A036_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A037_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A038_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A039_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A040_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A041_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A042_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A043_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A044_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A045_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A046_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A047_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A048_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P001R001A049_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A001_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A002_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A003_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A004_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A005_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A006_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A007_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A008_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A009_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A010_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A011_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A012_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A013_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A014_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A015_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A016_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A017_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A018_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A019_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A020_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A021_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A022_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A023_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A024_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A025_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A026_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A027_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A028_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A029_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A030_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A031_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A032_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A033_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A034_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A035_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A036_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A037_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A038_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A039_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A040_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A041_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A042_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A043_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A044_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A045_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A046_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A047_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A048_rgb.avi"
# Extracting video "./data/ntu/videos/S001C001P003R001A049_rgb.avi"
